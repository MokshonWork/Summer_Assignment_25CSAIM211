# %% [markdown]
# 101. Write a program to Create number guessing game.

# %%
import random

secret = random.randint(1, 100)

while True:
    guess = int(input("Enter your guess (1-100): "))
    print(f"You entered: {guess}")

    if guess < secret:
        print("Too low! Try again.")
    elif guess > secret:
        print("Too high! Try again.")
    else:
        print(f"Congratulations! You guessed the number {secret}.")
        break
# Out:
# You entered: 5
# Too low! Try again.
# You entered: 88
# Too high! Try again.
# You entered: 50
# Too high! Try again.
# You entered: 40
# Too high! Try again.
# You entered: 30
# Too high! Try again.
# You entered: 20
# Too low! Try again.
# You entered: 25
# Too low! Try again.
# You entered: 28
# Too low! Try again.
# You entered: 29
# Congratulations! You guessed the number 29.

# %% [markdown]
# 102. Write a program to Create voting eligibility system.

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print(f"Name: {name}")
print(f"Age: {age}")

if age >= 18:
    print(f"{name}, you are eligible to vote.")
else:
    print(f"{name}, you are not eligible to vote.")
# Out:
# Name: mox
# Age: 19
# mox, you are eligible to vote.

# %% [markdown]
# 103. Write a program to Create ATM simulation.

# %%
balance = 1000

while True:
    print("\n-- ATM MENU --")
    print("1. Check Balance")
    print("2. Deposit")
    print("3. Withdraw")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        print(f"Your current balance is: {balance}")

    elif choice == 2:
        amount = float(input("Enter deposit amount: "))
        balance += amount
        print(f"You deposited: {amount}")
        print(f"New balance: {balance}")

    elif choice == 3:
        amount = float(input("Enter withdrawal amount: "))
        if amount <= balance:
            balance -= amount
            print(f"You withdrew: {amount}")
            print(f"Remaining balance: {balance}")
        else:
            print("Insufficient balance!")

    elif choice == 4:
        print("Thank you for using the ATM!")
        break

    else:
        print("Invalid choice! Please try again.")
# Out:
# -- ATM MENU --
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Your current balance is: 1000
#
# -- ATM MENU --
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# You withdrew: 50.0
# Remaining balance: 950.0
#
# -- ATM MENU --
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Thank you for using the ATM!

# %% [markdown]
# 104. Write a program to Create quiz application.

# %%
score = 0

print("-- Tech Quiz --")

answer = input("1. Which programming language is known as the language of AI and Machine Learning? ")
print(f"You entered: {answer}")

if answer.lower() == "python":
    print("Correct!")
    score += 1
else:
    print("Wrong! The correct answer is Python.")

answer = input("2. What does CPU stand for? ")
print(f"You entered: {answer}")

if answer.lower() == "central processing unit":
    print("Correct!")
    score += 1
else:
    print("Wrong! The correct answer is Central Processing Unit.")

answer = input("3. Which company developed the Windows operating system? ")
print(f"You entered: {answer}")

if answer.lower() == "microsoft":
    print("Correct!")
    score += 1
else:
    print("Wrong! The correct answer is Microsoft.")

answer = input("4. Which data structure works on the LIFO principle? ")
print(f"You entered: {answer}")

if answer.lower() == "stack":
    print("Correct!")
    score += 1
else:
    print("Wrong! The correct answer is Stack.")

answer = input("5. What does HTML stand for? ")
print(f"You entered: {answer}")

if answer.lower() == "hypertext markup language":
    print("Correct!")
    score += 1
else:
    print("Wrong! The correct answer is HyperText Markup Language.")

print(f"\nYour final score is: {score}/5")
# Out:
# -- Tech Quiz --
# You entered: python
# Correct!
# You entered: central processing unit
# Correct!
# You entered: microsoft
# Correct!
# You entered: linked list
# Wrong! The correct answer is Stack.
# You entered: hypertext markup kanguage
# Wrong! The correct answer is HyperText Markup Language.
#
# Your final score is: 3/5
