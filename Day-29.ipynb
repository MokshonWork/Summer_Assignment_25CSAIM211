# %% [markdown]
# 113. Write a program to Create menu-driven calculator.

# %%
print("===== Calculator =====")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter your choice (1-4): "))

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == 1:
    result = num1 + num2
    print(f"Result = {result}")

elif choice == 2:
    result = num1 - num2
    print(f"Result = {result}")

elif choice == 3:
    result = num1 * num2
    print(f"Result = {result}")

elif choice == 4:
    if num2 != 0:
        result = num1 / num2
        print(f"Result = {result}")
    else:
        print("Division by zero is not allowed.")

else:
    print("Invalid Choice.")
# Out:
# ===== Calculator =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Result = 42.0

# %% [markdown]
# 114. Write a program to Create menu-driven array operations system.

# %%
arr = []

while True:
    print("\n========== ARRAY MENU ==========")
    print("1. Insert Element")
    print("2. Display Elements")
    print("3. Search Element")
    print("4. Update Element")
    print("5. Delete Element")
    print("6. Exit")

    choice = int(input("\nEnter your choice: "))

    if choice == 1:
        element = int(input("Enter element to insert: "))
        arr += [element]
        print(f"{element} inserted successfully!")

    elif choice == 2:
        if arr == []:
            print("Array is empty!")
        else:
            print("\nArray Elements:")
            i = 0
            while True:
                try:
                    print(f"Index {i} : {arr[i]}")
                    i += 1
                except IndexError:
                    break

    elif choice == 3:
        if arr == []:
            print("Array is empty!")
        else:
            key = int(input("Enter element to search: "))
            i = 0
            found = False

            while True:
                try:
                    if arr[i] == key:
                        print(f"{key} found at index {i}.")
                        found = True
                        break
                    i += 1
                except IndexError:
                    break

            if not found:
                print(f"{key} not found in the array.")

    elif choice == 4:
        if arr == []:
            print("Array is empty!")
        else:
            index = int(input("Enter index to update: "))
            try:
                print(f"Current value = {arr[index]}")
                new_value = int(input("Enter new value: "))
                arr[index] = new_value
                print(f"Index {index} updated successfully!")
            except IndexError:
                print("Invalid index!")

    elif choice == 5:
        if arr == []:
            print("Array is empty!")
        else:
            index = int(input("Enter index to delete: "))
            try:
                deleted = arr[index]
                del arr[index]
                print(f"{deleted} deleted successfully!")
            except IndexError:
                print("Invalid index!")

    elif choice == 6:
        print("Thank you! Program terminated.")
        break

    else:
        print("Invalid choice! Please enter a number between 1 and 6.")
# Out:
# ========== ARRAY MENU ==========
# 1. Insert Element
# 2. Display Elements
# 3. Search Element
# 4. Update Element
# 5. Delete Element
# 6. Exit
# 45 inserted successfully!
#
# ========== ARRAY MENU ==========
# 1. Insert Element
# 2. Display Elements
# 3. Search Element
# 4. Update Element
# 5. Delete Element
# 6. Exit
# 90 inserted successfully!
#
# ========== ARRAY MENU ==========
# 1. Insert Element
# 2. Display Elements
# 3. Search Element
# 4. Update Element
# 5. Delete Element
# 6. Exit
#
# Array Elements:
# Index 0 : 45
# Index 1 : 90
#
# ========== ARRAY MENU ==========
# 1. Insert Element
# 2. Display Elements
# 3. Search Element
# 4. Update Element
# 5. Delete Element
# 6. Exit
# 90 found at index 1.
#
# ========== ARRAY MENU ==========
# 1. Insert Element
# 2. Display Elements
# 3. Search Element
# 4. Update Element
# 5. Delete Element
# 6. Exit
# Thank you! Program terminated.

# %% [markdown]
# 115. Write a program to Create menu-driven string operations system.

# %%
string = input("Enter the initial string: ")

while True:
    print("\n========== STRING MENU ==========")
    print("1. Display String")
    print("2. Concatenate String")
    print("3. Find Length")
    print("4. Convert to Uppercase")
    print("5. Convert to Lowercase")
    print("6. Reverse String")
    print("7. Exit")

    choice = int(input("\nEnter your choice: "))

    if choice == 1:
        print(f"Current String: {string}")

    elif choice == 2:
        new_str = input("Enter another string: ")
        string = string + new_str
        print(f"Updated String: {string}")

    elif choice == 3:
        count = 0
        for ch in string:
            count += 1
        print(f"Length of string = {count}")

    elif choice == 4:
        print(f"Uppercase String: {string.upper()}")

    elif choice == 5:
        print(f"Lowercase String: {string.lower()}")

    elif choice == 6:
        rev = ""
        i = -1
        while True:
            try:
                rev += string[i]
                i -= 1
            except IndexError:
                break
        print(f"Reversed String: {rev}")

    elif choice == 7:
        print("Thank you! Program terminated.")
        break

    else:
        print("Invalid choice! Please enter a number between 1 and 7.")
# Out:
# ========== STRING MENU ==========
# 1. Display String
# 2. Concatenate String
# 3. Find Length
# 4. Convert to Uppercase
# 5. Convert to Lowercase
# 6. Reverse String
# 7. Exit
# Current String: hellow
#
# ========== STRING MENU ==========
# 1. Display String
# 2. Concatenate String
# 3. Find Length
# 4. Convert to Uppercase
# 5. Convert to Lowercase
# 6. Reverse String
# 7. Exit
# Updated String: hellow world
#
# ========== STRING MENU ==========
# 1. Display String
# 2. Concatenate String
# 3. Find Length
# 4. Convert to Uppercase
# 5. Convert to Lowercase
# 6. Reverse String
# 7. Exit
# Thank you! Program terminated.

# %% [markdown]
# 116. Write a program to Create inventory management system.

# %%
inventory = {}

while True:
    print("\n========== INVENTORY MANAGEMENT SYSTEM ==========")
    print("1. Add Product")
    print("2. Display Inventory")
    print("3. Search Product")
    print("4. Update Product")
    print("5. Delete Product")
    print("6. Exit")

    try:
        choice = int(input("\nEnter your choice: "))
    except ValueError:
        print("Please enter a valid number!")
        continue

    if choice == 1:
        product = input("Enter product name: ")
        quantity = int(input("Enter quantity: "))
        price = float(input("Enter price: "))

        inventory[product] = {
            "Quantity": quantity,
            "Price": price
        }

        print(f"{product} added successfully!")

    elif choice == 2:
        if inventory == {}:
            print("Inventory is empty!")
        else:
            print("\n----------- INVENTORY -----------")
            print("Product\t\tQuantity\tPrice")
            print("----------------------------------------")

            for product, details in inventory.items():
                print(f"{product}\t\t{details['Quantity']}\t\t{details['Price']}")

    elif choice == 3:
        product = input("Enter product name to search: ")

        if product in inventory:
            print(f"\nProduct : {product}")
            print(f"Quantity: {inventory[product]['Quantity']}")
            print(f"Price   : {inventory[product]['Price']}")
        else:
            print("Product not found!")

    elif choice == 4:
        product = input("Enter product name to update: ")

        if product in inventory:
            quantity = int(input("Enter new quantity: "))
            price = float(input("Enter new price: "))

            inventory[product]["Quantity"] = quantity
            inventory[product]["Price"] = price

            print(f"{product} updated successfully!")
        else:
            print("Product not found!")

    elif choice == 5:
        product = input("Enter product name to delete: ")

        if product in inventory:
            del inventory[product]
            print(f"{product} deleted successfully!")
        else:
            print("Product not found!")

    elif choice == 6:
        print("Thank you! Exiting program...")
        break

    else:
        print("Invalid choice! Please choose between 1 and 6.")
# Out:
# ========== INVENTORY MANAGEMENT SYSTEM ==========
# 1. Add Product
# 2. Display Inventory
# 3. Search Product
# 4. Update Product
# 5. Delete Product
# 6. Exit
# laptop added successfully!
#
# ========== INVENTORY MANAGEMENT SYSTEM ==========
# 1. Add Product
# 2. Display Inventory
# 3. Search Product
# 4. Update Product
# 5. Delete Product
# 6. Exit
#
# ----------- INVENTORY -----------
# Product		Quantity	Price
# ----------------------------------------
# laptop		10		55000.0
#
# ========== INVENTORY MANAGEMENT SYSTEM ==========
# 1. Add Product
# 2. Display Inventory
# 3. Search Product
# 4. Update Product
# 5. Delete Product
# 6. Exit
#
# Product : laptop
# Quantity: 10
# Price   : 55000.0
#
# ========== INVENTORY MANAGEMENT SYSTEM ==========
# 1. Add Product
# 2. Display Inventory
# 3. Search Product
# 4. Update Product
# 5. Delete Product
# 6. Exit
# Thank you! Exiting program...
