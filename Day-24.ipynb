# %% [markdown]
# 93. Write a program to Check string rotation.

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

if len(str1) == len(str2) and str2 in (str1 + str1):
    print(f'"{str2}" is a rotation of "{str1}".')
else:
    print(f'"{str2}" is not a rotation of "{str1}".')
# Out:
# "hemlo" is not a rotation of "hello".

# %% [markdown]
# 94. Write a program to Compress a string.

# %%
s = input("Enter a string: ")
print(f"You entered: {s}")
compressed = ""
count = 1
for i in range(len(s)):
    if i < len(s) - 1 and s[i] == s[i + 1]:
        count = count + 1
    else:
        compressed = compressed + s[i] + str(count)
        count = 1

print(f"Compressed string: {compressed}")
# Out:
# You entered: aaaabbbbddffuuu
# Compressed string: a4b4d2f2u3

# %% [markdown]
# 95. Write a program to Find longest word.

# %%
sentence = input("Enter a sentence: ")

words = sentence.split()

longest = words[0]

for word in words:
    if len(word) > len(longest):
        longest = word

print(f"Longest word: {longest}")
print(f"Length: {len(longest)}")
# Out:
# Longest word: whatsup
# Length: 7

# %% [markdown]
# 96. Write a program to remove duplicates

# %%
s = input("Enter a string: ")

result = ""
print(f"You entered: {s}")

for ch in s:
    if ch not in result:
        result = result + ch

print(f"String after removing duplicates: {result}")
# Out:
# You entered: aaaabbbbcccdddddfffuuuuu
# String after removing duplicates: abcdfu
